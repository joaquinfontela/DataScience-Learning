# %%
import numpy as np

# %%
# %matplotlib notebook
# graficos de manera interactiva

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Tenemos el siguiente sistema de ecuaciones:
#
# #### y = 3x + 5
# #### y = -x + 3
# #### y = 2x + 1

# %%
x = np.arange(-6,6)

y1 = 3*x + 5
y2 = -x + 3
y3 = 2*x + 1

# %%
plt.figure()

plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)

plt.xlim(-8,8)
plt.ylim(-8,8)

plt.axvline(x=0, color="grey")
plt.axhline(y=0, color="grey")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# #### No hay ningun punto que intercepte todas las rectas: no tiene solución.

# %% [markdown]
# ### Ahora haremos un sistema solo con las dos últimas ecuaciones:

# %%
plt.figure()

plt.plot(x,y2)
plt.plot(x,y3)

plt.xlim(-8,8)
plt.ylim(-8,8)

plt.axvline(x=0, color="grey")
plt.axhline(y=0, color="grey")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# ### Y ahora mostraremos el caso de infinitas soluciones:

# %%
plt.figure()

plt.plot(x,y3)

plt.xlim(-8,8)
plt.ylim(-8,8)

plt.axvline(x=0, color="grey")
plt.axhline(y=0, color="grey")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# ### Sin solución --> Incompatible
# ### Una solución --> Compatible determinado
# ### Infinitas soluciones --> Compatible indeterminado
