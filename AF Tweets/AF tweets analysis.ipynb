# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### I have been given a dataset about Argentina's president, Alberto Fernandez, in order to analyze the relation between comments, tweets and likes.

# %%
df = pd.read_csv('./alberto3_tweets - alberto3_tweets.csv')

# %%
df
# Out:
#               UserName     Handle                 Timestamp  \
# 0    Alberto Fernández  @alferdez  2021-12-09T23:29:30.000Z
# 1    Alberto Fernández  @alferdez  2021-12-09T17:02:42.000Z
# 2    Alberto Fernández  @alferdez  2021-12-09T11:06:37.000Z
# 3    Alberto Fernández  @alferdez  2021-12-02T21:04:21.000Z
# 4    Alberto Fernández  @alferdez  2021-12-02T21:04:21.000Z
# ..                 ...        ...                       ...
# 659  Alberto Fernández  @alferdez  2019-12-10T18:05:13.000Z
# 660  Alberto Fernández  @alferdez  2019-12-10T15:47:12.000Z
# 661  Alberto Fernández  @alferdez  2019-12-10T14:43:02.000Z
# 662  Alberto Fernández  @alferdez  2019-12-10T10:31:13.000Z
# 663  Alberto Fernández  @alferdez  2019-12-10T14:43:02.000Z
#
#                                                   Text  Comments  Retweets  \
# 0    Alberto Fernández\n@alferdez\n·\n9 dic. Hace 2...       670       453
# 1    Alberto Fernández\n@alferdez\n·\n9 dic.Este vi...      1000      1500
# 2    Alberto Fernández\n@alferdez\n·\n9 dic.Las 12 ...       579       496
# 3    Alberto Fernández\n@alferdez\n·\n2 dic.Agradez...        81       116
# 4    Alberto Fernández\n@alferdez\n·\n2 dic.He deci...       384       482
# ..                                                 ...       ...       ...
# 659  Alberto Fernández\n@alferdez\n·\n10 dic. 2019E...       173      1300
# 660  Alberto Fernández\n@alferdez\n·\n10 dic. 20191...      1900     16700
# 661  Alberto Fernández\n@alferdez\n·\n10 dic. 2019E...       774      5000
# 662  Alberto Fernández\n@alferdez\n·\n10 dic. 2019G...     11400     25200
# 663  Alberto Fernández\n@alferdez\n·\n10 dic. 2019E...       774      5000
#
#       Likes Unnamed: 7
# 0      1500   FILA 250
# 1      4800        NaN
# 2      1900        NaN
# 3       445        NaN
# 4      1500        NaN
# ..      ...        ...
# 659    5700        NaN
# 660   79300        NaN
# 661   18300        NaN
# 662  152300        NaN
# 663   18300        NaN
#
# [664 rows x 8 columns]

# %% [markdown]
# ### I will now drop an useless column.

# %%
df.drop(columns = 'Unnamed: 7', inplace=True)

# %%
df
# Out:
#               UserName     Handle                 Timestamp  \
# 0    Alberto Fernández  @alferdez  2021-12-09T23:29:30.000Z
# 1    Alberto Fernández  @alferdez  2021-12-09T17:02:42.000Z
# 2    Alberto Fernández  @alferdez  2021-12-09T11:06:37.000Z
# 3    Alberto Fernández  @alferdez  2021-12-02T21:04:21.000Z
# 4    Alberto Fernández  @alferdez  2021-12-02T21:04:21.000Z
# ..                 ...        ...                       ...
# 659  Alberto Fernández  @alferdez  2019-12-10T18:05:13.000Z
# 660  Alberto Fernández  @alferdez  2019-12-10T15:47:12.000Z
# 661  Alberto Fernández  @alferdez  2019-12-10T14:43:02.000Z
# 662  Alberto Fernández  @alferdez  2019-12-10T10:31:13.000Z
# 663  Alberto Fernández  @alferdez  2019-12-10T14:43:02.000Z
#
#                                                   Text  Comments  Retweets  \
# 0    Alberto Fernández\n@alferdez\n·\n9 dic. Hace 2...       670       453
# 1    Alberto Fernández\n@alferdez\n·\n9 dic.Este vi...      1000      1500
# 2    Alberto Fernández\n@alferdez\n·\n9 dic.Las 12 ...       579       496
# 3    Alberto Fernández\n@alferdez\n·\n2 dic.Agradez...        81       116
# 4    Alberto Fernández\n@alferdez\n·\n2 dic.He deci...       384       482
# ..                                                 ...       ...       ...
# 659  Alberto Fernández\n@alferdez\n·\n10 dic. 2019E...       173      1300
# 660  Alberto Fernández\n@alferdez\n·\n10 dic. 20191...      1900     16700
# 661  Alberto Fernández\n@alferdez\n·\n10 dic. 2019E...       774      5000
# 662  Alberto Fernández\n@alferdez\n·\n10 dic. 2019G...     11400     25200
# 663  Alberto Fernández\n@alferdez\n·\n10 dic. 2019E...       774      5000
#
#       Likes
# 0      1500
# 1      4800
# 2      1900
# 3       445
# 4      1500
# ..      ...
# 659    5700
# 660   79300
# 661   18300
# 662  152300
# 663   18300
#
# [664 rows x 7 columns]

# %% [markdown]
# ### We'll now convert Timestamp column to pandas datetime type.

# %%
df['month_year'] = df['Timestamp'].str.slice(0,7)
df['Timestamp'] = pd.to_datetime(df['Timestamp'].str.slice(0,10))

# %%
df
# Out:
#               UserName     Handle  Timestamp  \
# 0    Alberto Fernández  @alferdez 2021-12-09
# 1    Alberto Fernández  @alferdez 2021-12-09
# 2    Alberto Fernández  @alferdez 2021-12-09
# 3    Alberto Fernández  @alferdez 2021-12-02
# 4    Alberto Fernández  @alferdez 2021-12-02
# ..                 ...        ...        ...
# 659  Alberto Fernández  @alferdez 2019-12-10
# 660  Alberto Fernández  @alferdez 2019-12-10
# 661  Alberto Fernández  @alferdez 2019-12-10
# 662  Alberto Fernández  @alferdez 2019-12-10
# 663  Alberto Fernández  @alferdez 2019-12-10
#
#                                                   Text  Comments  Retweets  \
# 0    Alberto Fernández\n@alferdez\n·\n9 dic. Hace 2...       670       453
# 1    Alberto Fernández\n@alferdez\n·\n9 dic.Este vi...      1000      1500
# 2    Alberto Fernández\n@alferdez\n·\n9 dic.Las 12 ...       579       496
# 3    Alberto Fernández\n@alferdez\n·\n2 dic.Agradez...        81       116
# 4    Alberto Fernández\n@alferdez\n·\n2 dic.He deci...       384       482
# ..                                                 ...       ...       ...
# 659  Alberto Fernández\n@alferdez\n·\n10 dic. 2019E...       173      1300
# 660  Alberto Fernández\n@alferdez\n·\n10 dic. 20191...      1900     16700
# 661  Alberto Fernández\n@alferdez\n·\n10 dic. 2019E...       774      5000
# 662  Alberto Fernández\n@alferdez\n·\n10 dic. 2019G...     11400     25200
# 663  Alberto Fernández\n@alferdez\n·\n10 dic. 2019E...       774      5000
#
#       Likes month_year
# 0      1500    2021-12
# 1      4800    2021-12
# 2      1900    2021-12
# 3       445    2021-12
# 4      1500    2021-12
# ..      ...        ...
# 659    5700    2019-12
# 660   79300    2019-12
# 661   18300    2019-12
# 662  152300    2019-12
# 663   18300    2019-12
#
# [664 rows x 8 columns]

# %% [markdown]
# ### I will sort all the different amounts of likes.

# %%
n_likes_sorted = sorted(df['Likes'].to_numpy())
n_registers = len(n_likes_sorted)
n_registers
# Out:
# 664

# %% [markdown]
# ### Then, I will calculate floor values of the ranges for my analysis so that each range has the same amount of registers.

# %% [markdown]
# ### In this case, I will use five ranges, number which can be changed by altering the n_ranges variable.

# %%
range_floors = []
n_ranges = 5
for i in range(n_ranges):
    range_floors.append(n_likes_sorted[i * n_registers // n_ranges])
range_floors
# Out:
# [2, 905, 2600, 4800, 10300]

# %% [markdown]
# ### I'll give each range an id.

# %%
range_dict = {i: f'{range_floors[i]}-{range_floors[i+1]}' for i in range(len(range_floors) - 1)}
range_dict[len(range_floors) - 1] = f'> {range_floors[-1]}'

# %%
range_dict
# Out:
# {0: '2-905', 1: '905-2600', 2: '2600-4800', 3: '4800-10300', 4: '> 10300'}

# %% [markdown]
# ### Now I will add a new column to a dataframe so that each row maps to one of the ranges created.

# %%
df['like_range'] = None
df['like_range_id'] = None

for i in range(len(range_floors) - 1):
    df.loc[(df['Likes'] >= range_floors[i]) & (df['Likes'] < range_floors[i+1]), 'like_range'] = range_dict[i]
    df.loc[(df['Likes'] >= range_floors[i]) & (df['Likes'] < range_floors[i+1]), 'like_range_id'] = i
    
df['like_range'] = df['like_range'].fillna(range_dict[len(range_floors) - 1])
df['like_range_id'] = df['like_range_id'].fillna(len(range_floors) - 1)
df
# Out:
#               UserName     Handle  Timestamp  \
# 0    Alberto Fernández  @alferdez 2021-12-09
# 1    Alberto Fernández  @alferdez 2021-12-09
# 2    Alberto Fernández  @alferdez 2021-12-09
# 3    Alberto Fernández  @alferdez 2021-12-02
# 4    Alberto Fernández  @alferdez 2021-12-02
# ..                 ...        ...        ...
# 659  Alberto Fernández  @alferdez 2019-12-10
# 660  Alberto Fernández  @alferdez 2019-12-10
# 661  Alberto Fernández  @alferdez 2019-12-10
# 662  Alberto Fernández  @alferdez 2019-12-10
# 663  Alberto Fernández  @alferdez 2019-12-10
#
#                                                   Text  Comments  Retweets  \
# 0    Alberto Fernández\n@alferdez\n·\n9 dic. Hace 2...       670       453
# 1    Alberto Fernández\n@alferdez\n·\n9 dic.Este vi...      1000      1500
# 2    Alberto Fernández\n@alferdez\n·\n9 dic.Las 12 ...       579       496
# 3    Alberto Fernández\n@alferdez\n·\n2 dic.Agradez...        81       116
# 4    Alberto Fernández\n@alferdez\n·\n2 dic.He deci...       384       482
# ..                                                 ...       ...       ...
# 659  Alberto Fernández\n@alferdez\n·\n10 dic. 2019E...       173      1300
# 660  Alberto Fernández\n@alferdez\n·\n10 dic. 20191...      1900     16700
# 661  Alberto Fernández\n@alferdez\n·\n10 dic. 2019E...       774      5000
# 662  Alberto Fernández\n@alferdez\n·\n10 dic. 2019G...     11400     25200
# 663  Alberto Fernández\n@alferdez\n·\n10 dic. 2019E...       774      5000
#
#       Likes month_year  like_range  like_range_id
# 0      1500    2021-12    905-2600              1
# 1      4800    2021-12  4800-10300              3
# 2      1900    2021-12    905-2600              1
# 3       445    2021-12       2-905              0
# 4      1500    2021-12    905-2600              1
# ..      ...        ...         ...            ...
# 659    5700    2019-12  4800-10300              3
# 660   79300    2019-12     > 10300              4
# 661   18300    2019-12     > 10300              4
# 662  152300    2019-12     > 10300              4
# 663   18300    2019-12     > 10300              4
#
# [664 rows x 10 columns]

# %% [markdown]
# ### Now we will get the average comments per like range.

# %%
like_ranges_vs_comments = df.groupby('like_range_id')[['Comments', 'like_range']].agg({'Comments':'mean'})
like_ranges_vs_comments
# Out:
#                   Comments
# like_range_id
# 0                54.583333
# 1               280.924242
# 2               513.390977
# 3              1058.582090
# 4              2274.330827

# %%
like_ranges_vs_comments.index = [range_dict[like_ranges_vs_comments.index[i]] for i in range(len(like_ranges_vs_comments))]

# %% [markdown]
# ### And we plot the relation between the variables.

# %%
like_ranges_vs_comments.plot(kind='bar', y = 'Comments', figsize=(10,10),\
                            xlabel = 'Tweets Like-ranges', ylabel = 'Comments average for range',
                            title = 'Likes vs Comments correlation', color = 'darkred')
# Out:
# <AxesSubplot:title={'center':'Likes vs Comments correlation'}, xlabel='Tweets Like-ranges', ylabel='Comments average for range'>

# %% [markdown]
# ### In the next rows, we will plot the same type of bar chart, but this time the Y axis represents the quotient between likes and comments for each given range.

# %%
df['Like_comm_quotient'] = df['Likes'] / df['Comments']
df
# Out:
#               UserName     Handle  Timestamp  \
# 0    Alberto Fernández  @alferdez 2021-12-09
# 1    Alberto Fernández  @alferdez 2021-12-09
# 2    Alberto Fernández  @alferdez 2021-12-09
# 3    Alberto Fernández  @alferdez 2021-12-02
# 4    Alberto Fernández  @alferdez 2021-12-02
# ..                 ...        ...        ...
# 659  Alberto Fernández  @alferdez 2019-12-10
# 660  Alberto Fernández  @alferdez 2019-12-10
# 661  Alberto Fernández  @alferdez 2019-12-10
# 662  Alberto Fernández  @alferdez 2019-12-10
# 663  Alberto Fernández  @alferdez 2019-12-10
#
#                                                   Text  Comments  Retweets  \
# 0    Alberto Fernández\n@alferdez\n·\n9 dic. Hace 2...       670       453
# 1    Alberto Fernández\n@alferdez\n·\n9 dic.Este vi...      1000      1500
# 2    Alberto Fernández\n@alferdez\n·\n9 dic.Las 12 ...       579       496
# 3    Alberto Fernández\n@alferdez\n·\n2 dic.Agradez...        81       116
# 4    Alberto Fernández\n@alferdez\n·\n2 dic.He deci...       384       482
# ..                                                 ...       ...       ...
# 659  Alberto Fernández\n@alferdez\n·\n10 dic. 2019E...       173      1300
# 660  Alberto Fernández\n@alferdez\n·\n10 dic. 20191...      1900     16700
# 661  Alberto Fernández\n@alferdez\n·\n10 dic. 2019E...       774      5000
# 662  Alberto Fernández\n@alferdez\n·\n10 dic. 2019G...     11400     25200
# 663  Alberto Fernández\n@alferdez\n·\n10 dic. 2019E...       774      5000
#
#       Likes month_year  like_range  like_range_id  Like_comm_quotient
# 0      1500    2021-12    905-2600              1            2.238806
# 1      4800    2021-12  4800-10300              3            4.800000
# 2      1900    2021-12    905-2600              1            3.281520
# 3       445    2021-12       2-905              0            5.493827
# 4      1500    2021-12    905-2600              1            3.906250
# ..      ...        ...         ...            ...                 ...
# 659    5700    2019-12  4800-10300              3           32.947977
# 660   79300    2019-12     > 10300              4           41.736842
# 661   18300    2019-12     > 10300              4           23.643411
# 662  152300    2019-12     > 10300              4           13.359649
# 663   18300    2019-12     > 10300              4           23.643411
#
# [664 rows x 11 columns]

# %%
like_ranges_vs_comment_quotient = df.groupby('like_range_id')[['Like_comm_quotient', 'like_range']].agg({'Like_comm_quotient':'mean'})
like_ranges_vs_comment_quotient
# Out:
#                Like_comm_quotient
# like_range_id
# 0                       15.743305
# 1                       13.864339
# 2                       15.546124
# 3                       12.148850
# 4                       19.482574

# %%
like_ranges_vs_comment_quotient.index = [range_dict[like_ranges_vs_comment_quotient.index[i]] for i in range(len(like_ranges_vs_comment_quotient))]

# %%
like_ranges_vs_comment_quotient.plot(kind='bar', y = 'Like_comm_quotient', figsize=(10,10),\
                            xlabel = 'Tweets Like-ranges', ylabel = 'Like/Comment quotient for range',
                            title = 'Likes / Comments correlation', color = 'darkblue')
# Out:
# <AxesSubplot:title={'center':'Likes / Comments correlation'}, xlabel='Tweets Like-ranges', ylabel='Like/Comment quotient for range'>

# %% [markdown]
# ### We will now plot the tendencies of likes, comments and retweets numbers of the last two years.

# %%
df['month'] = df['Timestamp'].dt.month
df['year'] = df['Timestamp'].dt.year

# %%
df
# Out:
#               UserName     Handle  Timestamp  \
# 0    Alberto Fernández  @alferdez 2021-12-09
# 1    Alberto Fernández  @alferdez 2021-12-09
# 2    Alberto Fernández  @alferdez 2021-12-09
# 3    Alberto Fernández  @alferdez 2021-12-02
# 4    Alberto Fernández  @alferdez 2021-12-02
# ..                 ...        ...        ...
# 659  Alberto Fernández  @alferdez 2019-12-10
# 660  Alberto Fernández  @alferdez 2019-12-10
# 661  Alberto Fernández  @alferdez 2019-12-10
# 662  Alberto Fernández  @alferdez 2019-12-10
# 663  Alberto Fernández  @alferdez 2019-12-10
#
#                                                   Text  Comments  Retweets  \
# 0    Alberto Fernández\n@alferdez\n·\n9 dic. Hace 2...       670       453
# 1    Alberto Fernández\n@alferdez\n·\n9 dic.Este vi...      1000      1500
# 2    Alberto Fernández\n@alferdez\n·\n9 dic.Las 12 ...       579       496
# 3    Alberto Fernández\n@alferdez\n·\n2 dic.Agradez...        81       116
# 4    Alberto Fernández\n@alferdez\n·\n2 dic.He deci...       384       482
# ..                                                 ...       ...       ...
# 659  Alberto Fernández\n@alferdez\n·\n10 dic. 2019E...       173      1300
# 660  Alberto Fernández\n@alferdez\n·\n10 dic. 20191...      1900     16700
# 661  Alberto Fernández\n@alferdez\n·\n10 dic. 2019E...       774      5000
# 662  Alberto Fernández\n@alferdez\n·\n10 dic. 2019G...     11400     25200
# 663  Alberto Fernández\n@alferdez\n·\n10 dic. 2019E...       774      5000
#
#       Likes month_year  like_range  like_range_id  Like_comm_quotient  month  \
# 0      1500    2021-12    905-2600              1            2.238806     12
# 1      4800    2021-12  4800-10300              3            4.800000     12
# 2      1900    2021-12    905-2600              1            3.281520     12
# 3       445    2021-12       2-905              0            5.493827     12
# 4      1500    2021-12    905-2600              1            3.906250     12
# ..      ...        ...         ...            ...                 ...    ...
# 659    5700    2019-12  4800-10300              3           32.947977     12
# 660   79300    2019-12     > 10300              4           41.736842     12
# 661   18300    2019-12     > 10300              4           23.643411     12
# 662  152300    2019-12     > 10300              4           13.359649     12
# 663   18300    2019-12     > 10300              4           23.643411     12
#
#      year
# 0    2021
# 1    2021
# 2    2021
# 3    2021
# 4    2021
# ..    ...
# 659  2019
# 660  2019
# 661  2019
# 662  2019
# 663  2019
#
# [664 rows x 13 columns]

# %%
df.groupby('month_year')['Likes'].agg('mean').plot(figsize = (20,10), color = 'darkred',
                                                  xlabel = 'Month', ylabel = 'Average likes per tweet in month',
                                                  title = "Average likes per Alberto Fernandez's tweets in months from 12/2019 to 12/2021",
                                                  linewidth = 2.5)
# Out:
# <AxesSubplot:title={'center':"Average likes per Alberto Fernandez's tweets in months from 12/2019 to 12/2021"}, xlabel='Month', ylabel='Average likes per tweet in month'>

# %%
df.groupby('month_year')['Comments'].agg('mean').plot(figsize = (20,10), color = 'darkblue',
                                                  xlabel = 'Month', ylabel = 'Average comments per tweet in month',
                                                  title = "Average comments per Alberto Fernandez's tweets in months from 12/2019 to 12/2021",
                                                  linewidth = 2.5)
# Out:
# <AxesSubplot:title={'center':"Average comments per Alberto Fernandez's tweets in months from 12/2019 to 12/2021"}, xlabel='Month', ylabel='Average comments per tweet in month'>

# %%
df.groupby('month_year')['Retweets'].agg('mean').plot(figsize = (20,10), color = 'darkred',
                                                  xlabel = 'Month', ylabel = 'Average retweets per tweet in month',
                                                  title = "Average retweets per Alberto Fernandez's tweets in months from 12/2019 to 12/2021",
                                                  linewidth = 2.5)
# Out:
# <AxesSubplot:title={'center':"Average retweets per Alberto Fernandez's tweets in months from 12/2019 to 12/2021"}, xlabel='Month', ylabel='Average retweets per tweet in month'>

# %% [markdown]
# ### We conclude that likes and retweets numbers appear to behave similarly, while comments numbers are more volatile.

# %%
df.groupby('month_year')[['Likes', 'Retweets']].agg('mean').plot(figsize = (20,10), color = ['red', 'lightgreen'],
                                                  xlabel = 'Month', ylabel = 'Average likes and retweets per tweet in month',
                                                  title = "Like and retweet comparison per Alberto Fernandez's tweets in months from 12/2019 to 12/2021",
                                                  linewidth = 2.5)
# Out:
# <AxesSubplot:title={'center':"Like and retweet comparison per Alberto Fernandez's tweets in months from 12/2019 to 12/2021"}, xlabel='Month', ylabel='Average likes and retweets per tweet in month'>

# %% [markdown]
# ### In the graphic above, we can reaffirm that likes and retweets numbers behave similarly (although in different scales), as they have been sharing their peaks and minimums since 12/2019.

# %%
df['Like_rt_quot'] = df['Likes']/df['Retweets']
df
# Out:
#               UserName     Handle  Timestamp  \
# 0    Alberto Fernández  @alferdez 2021-12-09
# 1    Alberto Fernández  @alferdez 2021-12-09
# 2    Alberto Fernández  @alferdez 2021-12-09
# 3    Alberto Fernández  @alferdez 2021-12-02
# 4    Alberto Fernández  @alferdez 2021-12-02
# ..                 ...        ...        ...
# 659  Alberto Fernández  @alferdez 2019-12-10
# 660  Alberto Fernández  @alferdez 2019-12-10
# 661  Alberto Fernández  @alferdez 2019-12-10
# 662  Alberto Fernández  @alferdez 2019-12-10
# 663  Alberto Fernández  @alferdez 2019-12-10
#
#                                                   Text  Comments  Retweets  \
# 0    Alberto Fernández\n@alferdez\n·\n9 dic. Hace 2...       670       453
# 1    Alberto Fernández\n@alferdez\n·\n9 dic.Este vi...      1000      1500
# 2    Alberto Fernández\n@alferdez\n·\n9 dic.Las 12 ...       579       496
# 3    Alberto Fernández\n@alferdez\n·\n2 dic.Agradez...        81       116
# 4    Alberto Fernández\n@alferdez\n·\n2 dic.He deci...       384       482
# ..                                                 ...       ...       ...
# 659  Alberto Fernández\n@alferdez\n·\n10 dic. 2019E...       173      1300
# 660  Alberto Fernández\n@alferdez\n·\n10 dic. 20191...      1900     16700
# 661  Alberto Fernández\n@alferdez\n·\n10 dic. 2019E...       774      5000
# 662  Alberto Fernández\n@alferdez\n·\n10 dic. 2019G...     11400     25200
# 663  Alberto Fernández\n@alferdez\n·\n10 dic. 2019E...       774      5000
#
#       Likes month_year  like_range  like_range_id  Like_comm_quotient  month  \
# 0      1500    2021-12    905-2600              1            2.238806     12
# 1      4800    2021-12  4800-10300              3            4.800000     12
# 2      1900    2021-12    905-2600              1            3.281520     12
# 3       445    2021-12       2-905              0            5.493827     12
# 4      1500    2021-12    905-2600              1            3.906250     12
# ..      ...        ...         ...            ...                 ...    ...
# 659    5700    2019-12  4800-10300              3           32.947977     12
# 660   79300    2019-12     > 10300              4           41.736842     12
# 661   18300    2019-12     > 10300              4           23.643411     12
# 662  152300    2019-12     > 10300              4           13.359649     12
# 663   18300    2019-12     > 10300              4           23.643411     12
#
#      year  Like_rt_quot
# 0    2021      3.311258
# 1    2021      3.200000
# 2    2021      3.830645
# 3    2021      3.836207
# 4    2021      3.112033
# ..    ...           ...
# 659  2019      4.384615
# 660  2019      4.748503
# 661  2019      3.660000
# 662  2019      6.043651
# 663  2019      3.660000
#
# [664 rows x 14 columns]

# %%
df.groupby('month_year')['Like_rt_quot'].agg('mean').plot(figsize = (20,10), color = ['darkorange'],
                                                  xlabel = 'Month', ylabel = 'Like-retweet quotient average per tweet in month',
                                                  title = "Like-retweet quotient per Alberto Fernandez's tweets in months from 12/2019 to 12/2021",
                                                  linewidth = 2.5)
# Out:
# <AxesSubplot:title={'center':"Like-retweet quotient per Alberto Fernandez's tweets in months from 12/2019 to 12/2021"}, xlabel='Month', ylabel='Like-retweet quotient average per tweet in month'>

# %% [markdown]
# ### We can observe that the quotient between likes and retweets always remains aproximately between 4.0 and 6.0 except for a rare peak around March 2020.

# %%
df
# Out:
#               UserName     Handle  Timestamp  \
# 0    Alberto Fernández  @alferdez 2021-12-09
# 1    Alberto Fernández  @alferdez 2021-12-09
# 2    Alberto Fernández  @alferdez 2021-12-09
# 3    Alberto Fernández  @alferdez 2021-12-02
# 4    Alberto Fernández  @alferdez 2021-12-02
# ..                 ...        ...        ...
# 659  Alberto Fernández  @alferdez 2019-12-10
# 660  Alberto Fernández  @alferdez 2019-12-10
# 661  Alberto Fernández  @alferdez 2019-12-10
# 662  Alberto Fernández  @alferdez 2019-12-10
# 663  Alberto Fernández  @alferdez 2019-12-10
#
#                                                   Text  Comments  Retweets  \
# 0    Alberto Fernández\n@alferdez\n·\n9 dic. Hace 2...       670       453
# 1    Alberto Fernández\n@alferdez\n·\n9 dic.Este vi...      1000      1500
# 2    Alberto Fernández\n@alferdez\n·\n9 dic.Las 12 ...       579       496
# 3    Alberto Fernández\n@alferdez\n·\n2 dic.Agradez...        81       116
# 4    Alberto Fernández\n@alferdez\n·\n2 dic.He deci...       384       482
# ..                                                 ...       ...       ...
# 659  Alberto Fernández\n@alferdez\n·\n10 dic. 2019E...       173      1300
# 660  Alberto Fernández\n@alferdez\n·\n10 dic. 20191...      1900     16700
# 661  Alberto Fernández\n@alferdez\n·\n10 dic. 2019E...       774      5000
# 662  Alberto Fernández\n@alferdez\n·\n10 dic. 2019G...     11400     25200
# 663  Alberto Fernández\n@alferdez\n·\n10 dic. 2019E...       774      5000
#
#       Likes month_year  like_range  like_range_id  Like_comm_quotient  month  \
# 0      1500    2021-12    905-2600              1            2.238806     12
# 1      4800    2021-12  4800-10300              3            4.800000     12
# 2      1900    2021-12    905-2600              1            3.281520     12
# 3       445    2021-12       2-905              0            5.493827     12
# 4      1500    2021-12    905-2600              1            3.906250     12
# ..      ...        ...         ...            ...                 ...    ...
# 659    5700    2019-12  4800-10300              3           32.947977     12
# 660   79300    2019-12     > 10300              4           41.736842     12
# 661   18300    2019-12     > 10300              4           23.643411     12
# 662  152300    2019-12     > 10300              4           13.359649     12
# 663   18300    2019-12     > 10300              4           23.643411     12
#
#      year  Like_rt_quot
# 0    2021      3.311258
# 1    2021      3.200000
# 2    2021      3.830645
# 3    2021      3.836207
# 4    2021      3.112033
# ..    ...           ...
# 659  2019      4.384615
# 660  2019      4.748503
# 661  2019      3.660000
# 662  2019      6.043651
# 663  2019      3.660000
#
# [664 rows x 14 columns]

# %% [markdown]
# ### Now, I will split the dataset by comments number ranges as I did with likes number.

# %%
n_comments_sorted = sorted(df['Comments'].to_numpy())

# %% [markdown]
# ### In this case, I will use five ranges, number which can be changed by altering the n_ranges variable.

# %%
range_floors = []
n_ranges = 5
for i in range(n_ranges):
    range_floors.append(n_comments_sorted[i * n_registers // n_ranges])
range_floors
# Out:
# [2, 68, 238, 609, 1200]

# %% [markdown]
# ### Again, I'll give each range an id.

# %%
range_dict = {i: f'{range_floors[i]}-{range_floors[i+1]}' for i in range(len(range_floors) - 1)}
range_dict[len(range_floors) - 1] = f'> {range_floors[-1]}'

# %%
range_dict
# Out:
# {0: '2-68', 1: '68-238', 2: '238-609', 3: '609-1200', 4: '> 1200'}

# %% [markdown]
# ### Now I will add a new column to a dataframe so that each row maps to one of the ranges created.

# %%
df['Comment Range'] = None
df['comment_range_id'] = None

for i in range(len(range_floors) - 1):
    df.loc[(df['Comments'] >= range_floors[i]) & (df['Comments'] < range_floors[i+1]), 'Comment Range'] = range_dict[i]
    df.loc[(df['Comments'] >= range_floors[i]) & (df['Comments'] < range_floors[i+1]), 'comment_range_id'] = i
    
df['Comment Range'] = df['Comment Range'].fillna(range_dict[len(range_floors) - 1])
df['comment_range_id'] = df['comment_range_id'].fillna(len(range_floors) - 1)
df
# Out:
#               UserName     Handle  Timestamp  \
# 0    Alberto Fernández  @alferdez 2021-12-09
# 1    Alberto Fernández  @alferdez 2021-12-09
# 2    Alberto Fernández  @alferdez 2021-12-09
# 3    Alberto Fernández  @alferdez 2021-12-02
# 4    Alberto Fernández  @alferdez 2021-12-02
# ..                 ...        ...        ...
# 659  Alberto Fernández  @alferdez 2019-12-10
# 660  Alberto Fernández  @alferdez 2019-12-10
# 661  Alberto Fernández  @alferdez 2019-12-10
# 662  Alberto Fernández  @alferdez 2019-12-10
# 663  Alberto Fernández  @alferdez 2019-12-10
#
#                                                   Text  Comments  Retweets  \
# 0    Alberto Fernández\n@alferdez\n·\n9 dic. Hace 2...       670       453
# 1    Alberto Fernández\n@alferdez\n·\n9 dic.Este vi...      1000      1500
# 2    Alberto Fernández\n@alferdez\n·\n9 dic.Las 12 ...       579       496
# 3    Alberto Fernández\n@alferdez\n·\n2 dic.Agradez...        81       116
# 4    Alberto Fernández\n@alferdez\n·\n2 dic.He deci...       384       482
# ..                                                 ...       ...       ...
# 659  Alberto Fernández\n@alferdez\n·\n10 dic. 2019E...       173      1300
# 660  Alberto Fernández\n@alferdez\n·\n10 dic. 20191...      1900     16700
# 661  Alberto Fernández\n@alferdez\n·\n10 dic. 2019E...       774      5000
# 662  Alberto Fernández\n@alferdez\n·\n10 dic. 2019G...     11400     25200
# 663  Alberto Fernández\n@alferdez\n·\n10 dic. 2019E...       774      5000
#
#       Likes month_year  like_range  like_range_id  Like_comm_quotient  month  \
# 0      1500    2021-12    905-2600              1            2.238806     12
# 1      4800    2021-12  4800-10300              3            4.800000     12
# 2      1900    2021-12    905-2600              1            3.281520     12
# 3       445    2021-12       2-905              0            5.493827     12
# 4      1500    2021-12    905-2600              1            3.906250     12
# ..      ...        ...         ...            ...                 ...    ...
# 659    5700    2019-12  4800-10300              3           32.947977     12
# 660   79300    2019-12     > 10300              4           41.736842     12
# 661   18300    2019-12     > 10300              4           23.643411     12
# 662  152300    2019-12     > 10300              4           13.359649     12
# 663   18300    2019-12     > 10300              4           23.643411     12
#
#      year  Like_rt_quot Comment Range  comment_range_id
# 0    2021      3.311258      609-1200                 3
# 1    2021      3.200000      609-1200                 3
# 2    2021      3.830645       238-609                 2
# 3    2021      3.836207        68-238                 1
# 4    2021      3.112033       238-609                 2
# ..    ...           ...           ...               ...
# 659  2019      4.384615        68-238                 1
# 660  2019      4.748503        > 1200                 4
# 661  2019      3.660000      609-1200                 3
# 662  2019      6.043651        > 1200                 4
# 663  2019      3.660000      609-1200                 3
#
# [664 rows x 16 columns]

# %% [markdown]
# ### The next thing I will do is create a dataframe in which rows are like number ranges, columns are comment number ranges, and values are the number of tweets in each category intersection.

# %%
ranges_comparison = df[['like_range', 'like_range_id', 'Comment Range', 'comment_range_id']]\
    .groupby('like_range').agg({'Comment Range': 'value_counts'})\
    .rename(columns = {'Comment Range': 'comment_range_count'})\
    .reset_index().pivot(index = 'like_range', columns = 'Comment Range', values = 'comment_range_count')\
    .fillna(0)
ranges_comparison
# Out:
# Comment Range   2-68  238-609  609-1200  68-238  > 1200
# like_range
# 2-905          101.0      5.0       0.0    26.0     0.0
# 2600-4800        6.0     48.0      32.0    35.0    12.0
# 4800-10300       1.0     33.0      47.0    10.0    43.0
# 905-2600        24.0     33.0      13.0    59.0     3.0
# > 10300          0.0     15.0      30.0     2.0    86.0

# %% [markdown]
# ### Now we will sort the rows and columns such that the ranges are sorted from least to greatest.

# %%
idx_order = sorted(ranges_comparison.index.to_list(), key=lambda i: int(i.split('-')[0]) if '-' in i else np.inf)
idx_order
# Out:
# ['2-905', '905-2600', '2600-4800', '4800-10300', '> 10300']

# %%
col_order = sorted(ranges_comparison.columns.to_list(), key=lambda c: int(c.split('-')[0]) if '-' in c else np.inf)
col_order
# Out:
# ['2-68', '68-238', '238-609', '609-1200', '> 1200']

# %% [markdown]
# ### Our final dataframe:

# %%
ranges_comparison = ranges_comparison.reindex(idx_order)[col_order]
ranges_comparison
# Out:
# Comment Range   2-68  68-238  238-609  609-1200  > 1200
# like_range
# 2-905          101.0    26.0      5.0       0.0     0.0
# 905-2600        24.0    59.0     33.0      13.0     3.0
# 2600-4800        6.0    35.0     48.0      32.0    12.0
# 4800-10300       1.0    10.0     33.0      47.0    43.0
# > 10300          0.0     2.0     15.0      30.0    86.0

# %% [markdown]
# ### And its plot:

# %%
ranges_comparison.plot(kind='bar', cmap = 'rainbow', figsize = (20,10),
                      xlabel = 'Like range', ylabel = 'Number of tweets',
                      title = 'Number of tweets classified by like and comment range')
# Out:
# <AxesSubplot:title={'center':'Number of tweets classified by like and comment range'}, xlabel='Like range', ylabel='Number of tweets'>
